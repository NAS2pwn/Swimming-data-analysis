# %% [markdown]
# # Playground SQL
#
# Pour rappel, on a 4 tables suivantes:
#
# - Athlete : id (primary key), name, gender, team
# - Event : id (primary key), location, year, distance, stroke, relay
# - Team : id (primary key), event_id (foreign key), athlete_id (foreign key)
# - Results : id (primary key), team_id (foreign key), results, rank, quit_reason
#
# Le but ici va être de s'entraîner sur des requêtes SQL avancées.

# %%
# Connexion à la base de données
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# Charger les variables d'environnement
load_dotenv()

username = os.getenv("DB_USERNAME")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
dbname = os.getenv("DB_NAME")

# Création de la base de données
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{dbname}')

# %% [markdown]
# GPT o1-mini, avec la connaissance du contexte, nous a concocté quelques exercices :
#
# Voici une série de défis SQL conçus pour vous aider à vous entraîner et à maîtriser l'utilisation des Common Table Expressions (CTEs), des fonctions de fenêtre (window functions) et des classements (RANKs) dans le contexte de votre base de données sur les résultats de natation olympique.
#
# 1. Top 3 Performers par Année et Style de Nage
#
# Écrivez une requête SQL utilisant un CTE et des fonctions de fenêtre pour identifier les trois athlètes les plus performants (les résultats les plus bas) dans chaque style de nage pour chaque année olympique.
#
# 2. Moyenne des Résultats par Équipe
#
# Utilisez une fonction de fenêtre pour calculer le temps moyen des résultats pour chaque équipe à travers tous les événements et listez les équipes dont la performance est supérieure à la moyenne générale.
#
# 3. Amélioration des Performances au Fil du Temps
#
# Employez un CTE pour organiser les données par athlète et année, puis utilisez des fonctions de fenêtre pour calculer la différence de résultats par rapport à l'année olympique précédente pour chaque athlète.
#
# 4. Classement de Participation aux Événements
#
# Classez les athlètes en fonction du nombre d'événements auxquels ils ont participé en utilisant RANK ou DENSE_RANK, et listez les dix athlètes les plus actifs.
#
# 5. Performance des Équipes de Relais
#
# Utilisez des fonctions de fenêtre pour déterminer quelles équipes de relais ont les résultats combinés les plus rapides et classez-les en conséquence.
#
# 6. Résultats Médians par Événement
#
# Écrivez une requête utilisant des fonctions de fenêtre pour calculer le temps médian des résultats pour chaque événement et identifiez comment chaque athlète se compare à la médiane.
#
# 7. Consistance des Performances des Athlètes
#
# Utilisez des CTE et des fonctions de fenêtre pour mesurer la consistance de chaque athlète en calculant l'écart type de leurs temps de résultats à travers différents événements, et classez-les du plus au moins constant.
#
# 8. Comparaison des Performances par Genre et Année
#
# Utilisez des fonctions de fenêtre pour comparer les résultats moyens entre les athlètes masculins et féminins pour chaque année, et classez l'évolution des performances par genre au fil du temps.
#
# 9. Domination des Équipes par Style de Nage
#
# Utilisez RANK pour identifier quelles équipes ont remporté le plus de médailles dans chaque catégorie de style de nage à travers toutes les années.
#
# 10. Plus Grande Amélioration des Résultats
#
# Utilisez des CTE pour identifier les athlètes qui ont montré la plus grande amélioration dans leurs résultats au fil des Jeux Olympiques successifs.
#
# ---
# Ces défis vous permettront de manipuler et d'analyser vos données de manière approfondie tout en renforçant vos compétences en SQL avancé. Bon entraînement !

# %% [markdown]
# ## Exercice 1 : Top 3 Performers par Année et Style de Nage

# %% [markdown]
# "Écrivez une requête SQL utilisant un CTE et des fonctions de fenêtre pour identifier les trois athlètes les plus performants (les résultats les plus bas) dans chaque style de nage pour chaque année olympique."
#
# On va pas compter les relais en revanche, parce qu'on a pas l'info de qui dans l'équipe a été meilleur dans le dataset.
#
# On va aussi prendre en compte la distance, ça n'a pas de sens de comparer les résultats UNIQUEMENT par style de nage.
#
# Voici le résultat en prenant en compte toutes les données, pas besoin de CTE ou de window function c'est trivial.

# %%
from sqlalchemy import text

session = engine.connect()

query = text("""
SELECT a.name, e.stroke, e.distance, e.year, r.rank
FROM athletes a
INNER JOIN teams t ON a.athlete_id = t.athlete_id
INNER JOIN events e ON t.event_id = e.event_id
INNER JOIN results r ON t.team_id = r.team_id
WHERE NOT e.is_relay
AND r.rank <= 3
AND r.rank > 0
ORDER BY e.year, e.stroke, e.distance, r.rank
""")

result = session.execute(query)
print(result.fetchall())

session.close()
# Out:
# [('Harry J. Hebner', 'Backstroke', 100, 1912, 1), ('Otto Fahr', 'Backstroke', 100, 1912, 2), ('Paul Kellner', 'Backstroke', 100, 1912, 3), ('Walter Bathe', 'Breaststroke', 200, 1912, 1), ('Willy Lützow', 'Breaststroke', 200, 1912, 2), ('Kurt Paul Malisch', 'Breaststroke', 200, 1912, 3), ('Walter Bathe', 'Breaststroke', 400, 1912, 1), ('Tor Henning', 'Breaststroke', 400, 1912, 2), ('Percy Courtman', 'Breaststroke', 400, 1912, 3), ('Fanny Durack', 'Freestyle', 100, 1912, 1), ('Duke Paoa Kahanamoku', 'Freestyle', 100, 1912, 1), ('Cecil Healy', 'Freestyle', 100, 1912, 2), ('Mina Wylie', 'Freestyle', 100, 1912, 2), ('Jennie Fletcher', 'Freestyle', 100, 1912, 3), ('Kenneth Huszagh', 'Freestyle', 100, 1912, 3), ('George Ritchie Hodgson', 'Freestyle', 400, 1912, 1), ('John Gatenby Hatfield', 'Freestyle', 400, 1912, 2), ('Harold H. Hardwick', 'Freestyle', 400, 1912, 3), ('George Ritchie Hodgson', 'Freestyle', 1500, 1912, 1), ('John Gatenby Hatfield', 'Freestyle', 1500, 1912, 2), ('Harold H. Hardwick', 'Freestyle', 1500, 1912, 3), ('Warren Paoa Kealoha', 'Backstroke', 100, 1920, 2), ('Raymond Kegeris', 'Backstroke', 100, 1920, 3), ('Hakan Malmrot', 'Breaststroke', 200, 1920, 3), ('Hakan Malmrot', 'Breaststroke', 400, 1920, 2), ('Tor Henning', 'Breaststroke', 400, 1920, 3), ('Duke Paoa Kahanamoku', 'Freestyle', 100, 1920, 1), ('Pua Kela Kealoha', 'Freestyle', 100, 1920, 2), ('Ethelda Bleibtrey', 'Freestyle', 100, 1920, 3), ('William Harris', 'Freestyle', 100, 1920, 3), ('Norman Ross', 'Freestyle', 400, 1920, 2), ('Ludy Langer', 'Freestyle', 400, 1920, 3), ('Norman Ross', 'Freestyle', 1500, 1920, 1), ('George Vernot', 'Freestyle', 1500, 1920, 2), ('Frank De Beaurepaire', 'Freestyle', 1500, 1920, 3), ('Sybil Bauer', 'Backstroke', 100, 1924, 1), ('Warren Paoa Kealoha', 'Backstroke', 100, 1924, 1), ('Phyllis Harding', 'Backstroke', 100, 1924, 2), ('Paul Wyatt', 'Backstroke', 100, 1924, 2), ('Aileen Riggin', 'Backstroke', 100, 1924, 3), ('Károly Bartha', 'Backstroke', 100, 1924, 3), ('Robert Skelton', 'Breaststroke', 200, 1924, 1), ('Lucille Morton', 'Breaststroke', 200, 1924, 1), ('Agnes Geraghty', 'Breaststroke', 200, 1924, 2), ('Joseph De Combe', 'Breaststroke', 200, 1924, 2), ('Gladys Carson', 'Breaststroke', 200, 1924, 3), ('Bill Kirschbaum', 'Breaststroke', 200, 1924, 3), ('Ethel Lackie', 'Freestyle', 100, 1924, 1), ('Duke Paoa Kahanamoku', 'Freestyle', 100, 1924, 1), ('Sam Kahanamoku', 'Freestyle', 100, 1924, 2), ('Mariechen Wehselau', 'Freestyle', 100, 1924, 2), ('Arne Borg', 'Freestyle', 100, 1924, 3), ('Gertrude Ederle', 'Freestyle', 100, 1924, 3), ('Johnny Weissmuller', 'Freestyle', 400, 1924, 1), ('Martha Norelius', 'Freestyle', 400, 1924, 1), ('Helen Wainwright', 'Freestyle', 400, 1924, 2), ('Arne Borg', 'Freestyle', 400, 1924, 2), ('Andrew Murray Charlton', 'Freestyle', 400, 1924, 3), ('Gertrude Ederle', 'Freestyle', 400, 1924, 3), ('Andrew Murray Charlton', 'Freestyle', 1500, 1924, 1), ('Arne Borg', 'Freestyle', 1500, 1924, 2), ('Frank De Beaurepaire', 'Freestyle', 1500, 1924, 3), ('Maria Johanna Philipsen-Braun', 'Backstroke', 100, 1928, 1), ('George Harold Kojac', 'Backstroke', 100, 1928, 1), ('Ellen Elizabeth King', 'Backstroke', 100, 1928, 2), ('Walter Laufer', 'Backstroke', 100, 1928, 2), ('Margaret Joyce Cooper', 'Backstroke', 100, 1928, 3), ('Paul Wyatt', 'Backstroke', 100, 1928, 3), ('Hilde Schrader', 'Breaststroke', 200, 1928, 1), ('Yoshiyuki Tsuruta', 'Breaststroke', 200, 1928, 1), ('Mietje Baron', 'Breaststroke', 200, 1928, 2), ('Erich Rademacher', 'Breaststroke', 200, 1928, 2), ('Teofilo Yldefonso', 'Breaststroke', 200, 1928, 3), ('Charlotte Mühe', 'Breaststroke', 200, 1928, 3), ('Albina Lucy Osipowich', 'Freestyle', 100, 1928, 1), ('Katsuo Takaishi', 'Freestyle', 100, 1928, 1), ('George Harold Kojac', 'Freestyle', 100, 1928, 2), ('Eleanor Saville', 'Freestyle', 100, 1928, 2), ('Margaret Joyce Cooper', 'Freestyle', 100, 1928, 3), ('Walter Laufer', 'Freestyle', 100, 1928, 3), ('Martha Norelius', 'Freestyle', 400, 192 ...

# %% [markdown]
# On va maintenant oublier que le rank a déjà été calculé et calculer cela nous-mêmes, on prendra quand même soin d'éliminer les tuples qui ont été disqualifiés pour prévenir tout résultat biaisé.

# %%
from sqlalchemy import text

session = engine.connect()

query = text("""
WITH QualifiedSoloAthletes AS (
    SELECT
        a.athlete_id, e.stroke, e.distance, e.year, a.name, r.results
    FROM athletes a
    INNER JOIN teams t ON a.athlete_id = t.athlete_id
    INNER JOIN events e ON t.event_id = e.event_id
    INNER JOIN results r ON t.team_id = r.team_id
    WHERE NOT e.is_relay
    AND r.rank > 0
)
SELECT 
    name, stroke, distance, year,
    RANK() OVER (PARTITION BY year, stroke, distance ORDER BY results ASC) AS rank
FROM QualifiedSoloAthletes
ORDER BY year, stroke, distance, rank
""")

result = session.execute(query)
print(result.fetchall())

session.close()
# Out:
# [('Harry J. Hebner', 'Backstroke', 100, 1912, 1), ('Otto Fahr', 'Backstroke', 100, 1912, 2), ('Paul Kellner', 'Backstroke', 100, 1912, 3), ('András Baronyi', 'Backstroke', 100, 1912, 4), ('Otto Gross', 'Backstroke', 100, 1912, 5), ('Walter Bathe', 'Breaststroke', 200, 1912, 1), ('Willy Lützow', 'Breaststroke', 200, 1912, 2), ('Kurt Paul Malisch', 'Breaststroke', 200, 1912, 3), ('Percy Courtman', 'Breaststroke', 200, 1912, 4), ('Walter Bathe', 'Breaststroke', 400, 1912, 1), ('Tor Henning', 'Breaststroke', 400, 1912, 2), ('Percy Courtman', 'Breaststroke', 400, 1912, 3), ('Kurt Paul Malisch', 'Breaststroke', 400, 1912, 4), ('Duke Paoa Kahanamoku', 'Freestyle', 100, 1912, 1), ('Cecil Healy', 'Freestyle', 100, 1912, 2), ('Kenneth Huszagh', 'Freestyle', 100, 1912, 3), ('Kurt Bretting', 'Freestyle', 100, 1912, 4), ('Walther Ramme', 'Freestyle', 100, 1912, 5), ('Fanny Durack', 'Freestyle', 100, 1912, 6), ('Mina Wylie', 'Freestyle', 100, 1912, 7), ('Jennie Fletcher', 'Freestyle', 100, 1912, 8), ('Grete Rosenberg', 'Freestyle', 100, 1912, 9), ('Annie Speirs', 'Freestyle', 100, 1912, 10), ('George Ritchie Hodgson', 'Freestyle', 400, 1912, 1), ('John Gatenby Hatfield', 'Freestyle', 400, 1912, 2), ('Harold H. Hardwick', 'Freestyle', 400, 1912, 3), ('Cecil Healy', 'Freestyle', 400, 1912, 4), ('Béla Las Torres', 'Freestyle', 400, 1912, 5), ('George Ritchie Hodgson', 'Freestyle', 1500, 1912, 1), ('John Gatenby Hatfield', 'Freestyle', 1500, 1912, 2), ('Harold H. Hardwick', 'Freestyle', 1500, 1912, 3), ('Warren Paoa Kealoha', 'Backstroke', 100, 1920, 1), ('Raymond Kegeris', 'Backstroke', 100, 1920, 2), ('Gerard Blitz', 'Backstroke', 100, 1920, 3), ('Perry Mcgillivray', 'Backstroke', 100, 1920, 4), ('Stubby Kruger', 'Backstroke', 100, 1920, 5), ('Hakan Malmrot', 'Breaststroke', 200, 1920, 1), ('Tor Henning', 'Breaststroke', 200, 1920, 2), ('Arvo Ossian Aaltonen', 'Breaststroke', 200, 1920, 3), ('Jack Zophar Howell', 'Breaststroke', 200, 1920, 4), ('Ivan Stedman', 'Breaststroke', 200, 1920, 4), ('Hakan Malmrot', 'Breaststroke', 400, 1920, 1), ('Tor Henning', 'Breaststroke', 400, 1920, 2), ('Arvo Ossian Aaltonen', 'Breaststroke', 400, 1920, 3), ('Jack Zophar Howell', 'Breaststroke', 400, 1920, 4), ('Per Cederblom', 'Breaststroke', 400, 1920, 5), ('Duke Paoa Kahanamoku', 'Freestyle', 100, 1920, 1), ('Pua Kela Kealoha', 'Freestyle', 100, 1920, 2), ('William Harris', 'Freestyle', 100, 1920, 3), ('Billy Herald', 'Freestyle', 100, 1920, 4), ('Ethelda Bleibtrey', 'Freestyle', 100, 1920, 5), ('Irene Guest', 'Freestyle', 100, 1920, 6), ('Frances Schroth', 'Freestyle', 100, 1920, 7), ('Constance Mabel Jeans', 'Freestyle', 100, 1920, 8), ('Violet Walrond', 'Freestyle', 100, 1920, 9), ('Jane Gylling', 'Freestyle', 100, 1920, 9), ('Norman Ross', 'Freestyle', 400, 1920, 1), ('Ludy Langer', 'Freestyle', 400, 1920, 2), ('George Vernot', 'Freestyle', 400, 1920, 3), ('Fred Kahele', 'Freestyle', 400, 1920, 4), ('Norman Ross', 'Freestyle', 1500, 1920, 1), ('George Vernot', 'Freestyle', 1500, 1920, 2), ('Frank De Beaurepaire', 'Freestyle', 1500, 1920, 3), ('Fred Kahele', 'Freestyle', 1500, 1920, 4), ('Eugene Bolden', 'Freestyle', 1500, 1920, 5), ('Warren Paoa Kealoha', 'Backstroke', 100, 1924, 1), ('Paul Wyatt', 'Backstroke', 100, 1924, 2), ('Károly Bartha', 'Backstroke', 100, 1924, 3), ('Gerard Blitz', 'Backstroke', 100, 1924, 4), ('Austin Rawlinson', 'Backstroke', 100, 1924, 5), ('Sybil Bauer', 'Backstroke', 100, 1924, 6), ('Phyllis Harding', 'Backstroke', 100, 1924, 7), ('Aileen Riggin', 'Backstroke', 100, 1924, 8), ('Florence Chambers', 'Backstroke', 100, 1924, 9), ('Jarmila Müllerova', 'Backstroke', 100, 1924, 10), ('Robert Skelton', 'Breaststroke', 200, 1924, 1), ('Joseph De Combe', 'Breaststroke', 200, 1924, 2), ('Bill Kirschbaum', 'Breaststroke', 200, 1924, 3), ('Bengt Linders', 'Breaststroke', 200, 1924, 4), ('Robert Wyss', 'Breaststroke', 200, 1924, 5), ('Lucille Morton', 'Breaststroke', 200, 1924, 6), ('Agnes Geraghty', 'Breaststroke', 200, 1924, 7), ('Gla ...
